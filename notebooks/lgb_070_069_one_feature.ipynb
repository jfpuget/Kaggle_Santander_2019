# %%
fname = 'lgb_070'

# %%
import numpy as np
import pandas as pd
import datetime
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

from tqdm import tqdm_notebook

import gc
import datetime

from sklearn.metrics import f1_score, log_loss
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.decomposition import PCA
import xgboost as xgb
import lightgbm as lgb

from scipy.stats import hmean, gmean
from scipy.special import expit, logit

pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100
pd.options.display.max_columns = 100

import pickle as pkl

# %%
import numpy as np 
from numba import jit

@jit
def fast_auc(y_true, y_prob):
    y_true = np.asarray(y_true)
    y_true = y_true[np.argsort(y_prob)]
    nfalse = 0
    auc = 0
    n = len(y_true)
    for i in range(n):
        y_i = y_true[i]
        nfalse += (1 - y_i)
        auc += y_i * nfalse
    auc /= (nfalse * (n - nfalse))
    return auc

def eval_auc (preds, dtrain):
    labels = dtrain.get_label()    
    return 'auc', fast_auc(labels, preds), True

# %%
def get_importances(clfs):
    importances = [clf.feature_importance('gain') for clf in clfs]
    importances = np.vstack(importances)
    mean_gain = np.mean(importances, axis=0)
    features = clfs[0].feature_name()
    data = pd.DataFrame({'gain':mean_gain, 'feature':features})
    plt.figure(figsize=(8, 30))
    sns.barplot(x='gain', y='feature', data=data.sort_values('gain', ascending=False))
    plt.tight_layout()
    return data

def get_ranks(y_pred):
    return pd.Series(y_pred).rank().values

def cross_validate_lgb(param, x_train, y_train, x_test, kf,  
                       num_boost_round, 
                       fname, nseed=1, verbose_eval=1,
                       target='target', featimp=False, save_pred=False,
                       use_auc=True,
                       early_stopping_rounds=150,
                       use_all_folds=True,
                       ):
    
    if save_pred:
        now = datetime.datetime.now()
        now = str(now.strftime('%Y-%m-%d-%H-%M-%S'))
        print('started at:', now)
        print('num bagging seeds:', nseed)
        fname = '../submissions/'+fname+'_'+now
        print(x_train.shape, x_test.shape)
        
    
    nfold = kf.n_splits
    print('nfold', nfold)
        
    val_pred = np.zeros((x_train.shape[0], nseed))
    test_pred = np.zeros((x_test.shape[0], nfold * nseed))
        
    print('num features:', x_train.shape[1])
    
    d_train = lgb.Dataset(x_train, label=y_train)
    if use_auc:
        metric = 'auc'
    else:
        metric = None
    history = lgb.cv(params, d_train, num_boost_round=num_boost_round, 
                     folds=kf, metrics=metric, fobj=None,
                     early_stopping_rounds=early_stopping_rounds, 
                    verbose_eval=verbose_eval, show_stdv=True, seed=0)
    if use_auc:
        best_round = np.argmax(history['auc-mean'])
    else:
        best_round = np.argmin(history['binary_logloss-mean'])
    print('best_round:', best_round)
    if best_round == 0:
        best_round = 1
    bsts = []
    for i, (train_index, test_index) in enumerate(kf.split(x_train, y_train)):
        print('train fold', i, end=' ')
        x_train_kf, x_test_kf = x_train.loc[train_index,:].copy(), x_train.loc[test_index,:].copy()
        y_train_kf, y_test_kf = y_train[train_index], y_train[test_index]

        d_train_kf = lgb.Dataset(x_train_kf, label=y_train_kf)
        d_test_kf = lgb.Dataset(x_test_kf, label=y_test_kf)
        
        train_fold_pred = 0
        
        feval = None
        if use_auc:
            feval=eval_auc
        for seed in range(nseed):
            param['seed'] = seed
            

            bst = lgb.train(param, d_train_kf, num_boost_round=best_round,
                                verbose_eval=None,
                                early_stopping_rounds=None, 
                               )
                
            bsts.append(bst)
            pred = bst.predict(x_test_kf)
            val_pred[test_index, seed] = (pred)
            pred = bst.predict(x_test)
            test_pred[:, i*nseed + seed] = (pred)
            train_fold_pred = train_fold_pred + bst.predict(x_train_kf)
            print('.', end='')
            
        train_fold_pred /= nseed
        print('train auc: %0.5f' % fast_auc(y_train_kf, train_fold_pred), end=' ')
        val_fold_pred = np.mean(val_pred[test_index,:], axis=1)  
        print('val auc: %0.5f' % fast_auc(y_test_kf, val_fold_pred))
        del d_train_kf
        del d_test_kf
        gc.collect()
        if featimp:
            importances = get_importances(bsts)
            plt.show()
        else:
            importances = None
        if use_all_folds == False:
            break
    
    
    print('saving raw train prediction to:', fname+'_train.npy')
    np.save(fname+'_train.npy', val_pred)
    print('saving raw test prediction to:', fname+'_test.npy')
    np.save(fname+'_test.npy', test_pred)
    
    epsilon = 1e-6

    train_expit = (val_pred + epsilon - val_pred.ravel().min())
    test_expit = (test_pred + epsilon - test_pred.ravel().min())
    train_expit /= (epsilon + train_expit.ravel().max())
    test_expit /= (epsilon + test_expit.ravel().max())
    
    train_pred_mean = np.mean(train_expit, axis=1)
    test_pred_mean = np.mean(test_expit, axis=1)        
    print('cv       mean auc:%0.5f' % fast_auc(y_train, train_pred_mean))

    if featimp:
        importances = get_importances(bsts)
    else:
        importances = None

    return importances, val_pred, test_pred, bsts, fname

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

features = train.columns[2:]

x_train = train[features].copy()
y_train = train.target.values
x_test = test[features].copy()

# %%
public_lb = np.load('../data/public_LB.npy')
private_lb = np.load('../data/private_LB.npy')

real_test = np.concatenate((public_lb, private_lb))
real_test.shape

real_test = x_test.iloc[real_test]

# %%
x_train.shape, y_train.shape, x_test.shape, real_test.shape
# Out:
# ((200000, 200), (200000,), (200000, 200), (100000, 200))

# %%
count_cols = []

for c in tqdm_notebook(features[:200]):
    count_col = c+'_count'
    tmp = pd.concat((x_train[c], real_test[c])).value_counts()
    x_train[count_col] = x_train[c].map(tmp).clip(0, 6)
    x_test[count_col] = x_test[c].map(tmp).clip(0, 6).fillna(1)
    count_cols.append(count_col)
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))

# %%
params =  {
    'boosting_type': 'gbdt',
  "objective"                  : "binary",
  "learning_rate"              : 0.01,
  "num_leaves"                 : 3,
    'feature_fraction':1,
  "bagging_fraction"           : 0.8,
  "bagging_freq"               : 1,
               #'min_data_in_leaf' : 80,
               #'min_sum_hessian_in_leaf' : 10.0,
     'nthread'                  : 20,
    'bin_construct_sample_cnt' : 1000000,
    'max_depth':2,
    'lambda_l2':2,
}

num_boost_round = 10000
verbose_eval=1000
early_stopping_rounds = 200

res = []

for c, count in zip(tqdm_notebook(features), count_cols): #[('var_28', 'var_28_count')]: #
    
    fname_var = '_'.join([fname, c])
    print(c)
    x_train_1 = x_train[[c, count]].copy()
    y_train = train.target.values
    x_test_1 = x_test[[c, count]].copy()


    for seed in range(1):
        print('***** seed %d *****' % seed)
        kf = StratifiedKFold(5, shuffle=True, random_state=seed)

        (importances_reglinear, train_pred_reglinear, test_pred_reglinear, bsts, fname_save
        ) = cross_validate_lgb(params, x_train_1, y_train, x_test_1, kf,  
                           num_boost_round, 
                           fname_var, nseed=1, verbose_eval=None,
                           target='target', featimp=False, save_pred=True,
                           use_auc=False,
                           early_stopping_rounds=early_stopping_rounds,
                               use_all_folds=True,
                           )
        res.append(fname_save)
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# var_0
# ***** seed 0 *****
# started at: 2019-03-27-09-04-50
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 800
# train fold 0 .train auc: 0.55550 val auc: 0.54871
# train fold 1 .train auc: 0.55639 val auc: 0.54207
# train fold 2 .train auc: 0.55611 val auc: 0.55044
# train fold 3 .train auc: 0.55640 val auc: 0.54868
# train fold 4 .train auc: 0.55603 val auc: 0.54896
# saving raw train prediction to: ../submissions/lgb_070_var_0_2019-03-27-09-04-50_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_0_2019-03-27-09-04-50_test.npy
# cv       mean auc:0.54739
# var_1
# ***** seed 0 *****
# started at: 2019-03-27-09-05-09
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1104
# train fold 0 .train auc: 0.55262 val auc: 0.54938
# train fold 1 .train auc: 0.55393 val auc: 0.54464
# train fold 2 .train auc: 0.55444 val auc: 0.54258
# train fold 3 .train auc: 0.55329 val auc: 0.54711
# train fold 4 .train auc: 0.55310 val auc: 0.54757
# saving raw train prediction to: ../submissions/lgb_070_var_1_2019-03-27-09-05-09_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_1_2019-03-27-09-05-09_test.npy
# cv       mean auc:0.54592
# var_2
# ***** seed 0 *****
# started at: 2019-03-27-09-05-33
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1003
# train fold 0 .train auc: 0.56135 val auc: 0.54640
# train fold 1 .train auc: 0.55845 val auc: 0.55616
# train fold 2 .train auc: 0.55908 val auc: 0.55229
# train fold 3 .train auc: 0.56059 val auc: 0.54562
# train fold 4 .train auc: 0.55821 val auc: 0.55595
# saving raw train prediction to: ../submissions/lgb_070_var_2_2019-03-27-09-05-33_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_2_2019-03-27-09-05-33_test.npy
# cv       mean auc:0.55080
# var_3
# ***** seed 0 *****
# started at: 2019-03-27-09-05-56
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 248
# train fold 0 .train auc: 0.51774 val auc: 0.50728
# train fold 1 .train auc: 0.51876 val auc: 0.50897
# train fold 2 .train auc: 0.51659 val auc: 0.51430
# train fold 3 .train auc: 0.51773 val auc: 0.50875
# train fold 4 .train auc: 0.51664 val auc: 0.51426
# saving raw train prediction to: ../submissions/lgb_070_var_3_2019-03-27-09-05-56_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_3_2019-03-27-09-05-56_test.npy
# cv       mean auc:0.50949
# var_4
# ***** seed 0 *****
# started at: 2019-03-27-09-06-03
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 289
# train fold 0 .train auc: 0.52047 val auc: 0.50706
# train fold 1 .train auc: 0.52119 val auc: 0.50628
# train fold 2 .train auc: 0.51986 val auc: 0.50280
# train fold 3 .train auc: 0.51899 val auc: 0.50779
# train fold 4 .train auc: 0.52184 val auc: 0.51483
# saving raw train prediction to: ../submissions/lgb_070_var_4_2019-03-27-09-06-03_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_4_2019-03-27-09-06-03_test.npy
# cv       mean auc:0.50754
# var_5
# ***** seed 0 *****
# started at: 2019-03-27-09-06-11
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 678
# train fold 0 .train auc: 0.53678 val auc: 0.52582
# train fold 1 .train auc: 0.53732 val auc: 0.52579
# train fold 2 .train auc: 0.53700 val auc: 0.52530
# train fold 3 .train auc: 0.53536 val auc: 0.53240
# train fold 4 .train auc: 0.53691 val auc: 0.52530
# saving raw train prediction to: ../submissions/lgb_070_var_5_2019-03-27-09-06-11_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_5_2019-03-27-09-06-11_test.npy
# cv       mean auc:0.52652
# var_6
# ***** seed 0 *****
# started at: 2019-03-27-09-06-27
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 736
# train fold 0 .train auc: 0.56506 val auc: 0.56189
# train fold 1 .train auc: 0.56673 val auc: 0.55675
# train fold 2 .train auc: 0.56699 val auc: 0.55825
# train fold 3 .train auc: 0.56352 val auc: 0.56577
# train fold 4 .train auc: 0.56720 val auc: 0.54860
# saving raw train prediction to: ../submissions/lgb_070_var_6_2019-03-27-09-06-27_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_6_2019-03-27-09-06-27_test.npy
# cv       mean auc:0.55761
# var_7
# ***** seed 0 *****
# started at: 2019-03-27-09-06-44
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 7
# train fold 0 .train auc: 0.50626 val auc: 0.50607
# train fold 1 .train auc: 0.51135 val auc: 0.50147
# train fold 2 .train auc: 0.50943 val auc: 0.49420
# train fold 3 .train auc: 0.50619 val auc: 0.50245
# train fold 4 .train auc: 0.51033 val auc: 0.49732
# saving raw train prediction to: ../submissions/lgb_070_var_7_2019-03-27-09-06-44_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_7_2019-03-27-09-06-44_test.npy
# cv       mean auc:0.49986
# var_8
# ***** seed 0 *****
# started at: 2019-03-27-09-06-47
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 364
# train fold 0 .train auc: 0.52784 val auc: 0.51336
# train fold 1 .train auc: 0.52620 val auc: 0.51964
# train fold 2 .train auc: 0.52687 val auc: 0.51505
# train fold 3 .train auc: 0.52573 val auc: 0.52198
# train fold 4 .train auc: 0.52520 val auc: 0.52499
# saving raw train prediction to: ../submissions/lgb_070_var_8_2019-03-27-09-06-47_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_8_2019-03-27-09-06-47_test.npy
# cv       mean auc:0.51817
# var_9
# ***** seed 0 *****
# started at: 2019-03-27-09-06-57
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 841
# train fold 0 .train auc: 0.54918 val auc: 0.54524
# train fold 1 .train auc: 0.54957 val auc: 0.54311
# train fold 2 .train auc: 0.54648 val auc: 0.55331
# train fold 3 .train auc: 0.55036 val auc: 0.53799
# train fold 4 .train auc: 0.55064 val auc: 0.53859
# saving raw train prediction to: ../submissions/lgb_070_var_9_2019-03-27-09-06-57_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_9_2019-03-27-09-06-57_test.npy
# cv       mean auc:0.54315
# var_10
# ***** seed 0 *****
# started at: 2019-03-27-09-07-15
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 104
# train fold 0 .train auc: 0.51237 val auc: 0.50168
# train fold 1 .train auc: 0.51257 val auc: 0.50343
# train fold 2 .train auc: 0.51414 val auc: 0.49555
# train fold 3 .train auc: 0.51299 val auc: 0.50308
# train fold 4 .train auc: 0.51150 val auc: 0.50280
# saving raw train prediction to: ../submissions/lgb_070_var_10_2019-03-27-09-07-15_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_10_2019-03-27-09-07-15_test.npy
# cv       mean auc:0.50118
# var_11
# ***** seed 0 *****
# started at: 2019-03-27-09-07-20
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 598
# train fold 0 .train auc: 0.52722 val auc: 0.51734
# train fold 1 .train auc: 0.52730 val auc: 0.52122
# train fold 2 .train auc: 0.52709 val auc: 0.52032
# train fold 3 .train auc: 0.52765 val auc: 0.51506
# train fold 4 .train auc: 0.52807 val auc: 0.51596
# saving raw train prediction to: ../submissions/lgb_070_var_11_2019-03-27-09-07-20_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_11_2019-03-27-09-07-20_test.npy
# cv       mean auc:0.51782
# var_12
# ***** seed 0 *****
# started at: 2019-03-27-09-07-35
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 387
# train fold 0 .train auc: 0.56411 val auc: 0.55970
# train fold 1 .train auc: 0.56485 val auc: 0.55888
# train fold 2 .train auc: 0.56455 val auc: 0.56223
# train fold 3 .train auc: 0.56264 val auc: 0.56555
# train fold 4 .train auc: 0.56616 val auc: 0.55205
# saving raw train prediction to: ../submissions/lgb_070_var_12_2019-03-27-09-07-35_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_12_2019-03-27-09-07-35_test.npy
# cv       mean auc:0.55907
# var_13
# ***** seed 0 *****
# started at: 2019-03-27-09-07-45
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 798
# train fold 0 .train auc: 0.55721 val auc: 0.56299
# train fold 1 .train auc: 0.55923 val auc: 0.55387
# train fold 2 .train auc: 0.55934 val auc: 0.55333
# train fold 3 .train auc: 0.55963 val auc: 0.55084
# train fold 4 .train auc: 0.56013 val auc: 0.54984
# saving raw train prediction to: ../submissions/lgb_070_var_13_2019-03-27-09-07-45_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_13_2019-03-27-09-07-45_test.npy
# cv       mean auc:0.55362
# var_14
# ***** seed 0 *****
# started at: 2019-03-27-09-08-04
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 112
# train fold 0 .train auc: 0.51281 val auc: 0.50569
# train fold 1 .train auc: 0.51529 val auc: 0.50765
# train fold 2 .train auc: 0.51420 val auc: 0.50166
# train fold 3 .train auc: 0.51456 val auc: 0.49848
# train fold 4 .train auc: 0.51453 val auc: 0.50846
# saving raw train prediction to: ../submissions/lgb_070_var_14_2019-03-27-09-08-04_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_14_2019-03-27-09-08-04_test.npy
# cv       mean auc:0.50412
# var_15
# ***** seed 0 *****
# started at: 2019-03-27-09-08-09
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 258
# train fold 0 .train auc: 0.52301 val auc: 0.51000
# train fold 1 .train auc: 0.52021 val auc: 0.52074
# train fold 2 .train auc: 0.52060 val auc: 0.51611
# train fold 3 .train auc: 0.52160 val auc: 0.51314
# train fold 4 .train auc: 0.52095 val auc: 0.51156
# saving raw train prediction to: ../submissions/lgb_070_var_15_2019-03-27-09-08-09_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_15_2019-03-27-09-08-09_test.npy
# cv       mean auc:0.51246
# var_16
# ***** seed 0 *****
# started at: 2019-03-27-09-08-16
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 160
# train fold 0 .train auc: 0.51623 val auc: 0.50778
# train fold 1 .train auc: 0.51799 val auc: 0.50295
# train fold 2 .train auc: 0.51875 val auc: 0.51209
# train fold 3 .train auc: 0.51551 val auc: 0.50748
# train fold 4 .train auc: 0.51830 val auc: 0.50546
# saving raw train prediction to: ../submissions/lgb_070_var_16_2019-03-27-09-08-16_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_16_2019-03-27-09-08-16_test.npy
# cv       mean auc:0.50596
# var_17
# ***** seed 0 *****
# started at: 2019-03-27-09-08-22
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 3
# train fold 0 .train auc: 0.50263 val auc: 0.50352
# train fold 1 .train auc: 0.50746 val auc: 0.50300
# train fold 2 .train auc: 0.50500 val auc: 0.49433
# train fold 3 .train auc: 0.50627 val auc: 0.49792
# train fold 4 .train auc: 0.50564 val auc: 0.49527
# saving raw train prediction to: ../submissions/lgb_070_var_17_2019-03-27-09-08-22_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_17_2019-03-27-09-08-22_test.npy
# cv       mean auc:0.49930
# var_18
# ***** seed 0 *****
# started at: 2019-03-27-09-08-25
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 886
# train fold 0 .train auc: 0.54789 val auc: 0.53337
# train fold 1 .train auc: 0.54523 val auc: 0.53949
# train fold 2 .train auc: 0.54637 val auc: 0.53645
# train fold 3 .train auc: 0.54505 val auc: 0.54182
# train fold 4 .train auc: 0.54549 val auc: 0.54195
# saving raw train prediction to: ../submissions/lgb_070_var_18_2019-03-27-09-08-25_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_18_2019-03-27-09-08-25_test.npy
# cv       mean auc:0.53802
# var_19
# ***** seed 0 *****
# started at: 2019-03-27-09-08-45
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 347
# train fold 0 .train auc: 0.52163 val auc: 0.51155
# train fold 1 .train auc: 0.52151 val auc: 0.51111
# train fold 2 .train auc: 0.52024 val auc: 0.51345
# train fold 3 .train auc: 0.52188 val auc: 0.50578
# train fold 4 .train auc: 0.52145 val auc: 0.51999
# saving raw train prediction to: ../submissions/lgb_070_var_19_2019-03-27-09-08-45_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_19_2019-03-27-09-08-45_test.npy
# cv       mean auc:0.51091
# var_20
# ***** seed 0 *****
# started at: 2019-03-27-09-08-54
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 678
# train fold 0 .train auc: 0.52957 val auc: 0.51783
# train fold 1 .train auc: 0.52846 val auc: 0.52086
# train fold 2 .train auc: 0.52866 val auc: 0.51664
# train fold 3 .train auc: 0.52956 val auc: 0.51452
# train fold 4 .train auc: 0.52775 val auc: 0.52378
# saving raw train prediction to: ../submissions/lgb_070_var_20_2019-03-27-09-08-54_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_20_2019-03-27-09-08-54_test.npy
# cv       mean auc:0.51789
# var_21
# ***** seed 0 *****
# started at: 2019-03-27-09-09-10
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 883
# train fold 0 .train auc: 0.56332 val auc: 0.55320
# train fold 1 .train auc: 0.56256 val auc: 0.55700
# train fold 2 .train auc: 0.56084 val auc: 0.56628
# train fold 3 .train auc: 0.56313 val auc: 0.55242
# train fold 4 .train auc: 0.56229 val auc: 0.55469
# saving raw train prediction to: ../submissions/lgb_070_var_21_2019-03-27-09-09-10_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_21_2019-03-27-09-09-10_test.npy
# cv       mean auc:0.55591
# var_22
# ***** seed 0 *****
# started at: 2019-03-27-09-09-30
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 810
# train fold 0 .train auc: 0.56037 val auc: 0.54256
# train fold 1 .train auc: 0.55806 val auc: 0.55754
# train fold 2 .train auc: 0.55842 val auc: 0.55290
# train fold 3 .train auc: 0.55541 val auc: 0.56328
# train fold 4 .train auc: 0.55965 val auc: 0.54877
# saving raw train prediction to: ../submissions/lgb_070_var_22_2019-03-27-09-09-30_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_22_2019-03-27-09-09-30_test.npy
# cv       mean auc:0.55255
# var_23
# ***** seed 0 *****
# started at: 2019-03-27-09-09-48
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 254
# train fold 0 .train auc: 0.52813 val auc: 0.52101
# train fold 1 .train auc: 0.52849 val auc: 0.51993
# train fold 2 .train auc: 0.52585 val auc: 0.52613
# train fold 3 .train auc: 0.52668 val auc: 0.52537
# train fold 4 .train auc: 0.52733 val auc: 0.52287
# saving raw train prediction to: ../submissions/lgb_070_var_23_2019-03-27-09-09-48_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_23_2019-03-27-09-09-48_test.npy
# cv       mean auc:0.52148
# var_24
# ***** seed 0 *****
# started at: 2019-03-27-09-09-56
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 824
# train fold 0 .train auc: 0.53585 val auc: 0.53120
# train fold 1 .train auc: 0.53797 val auc: 0.52358
# train fold 2 .train auc: 0.53664 val auc: 0.52738
# train fold 3 .train auc: 0.53496 val auc: 0.53312
# train fold 4 .train auc: 0.53683 val auc: 0.52811
# saving raw train prediction to: ../submissions/lgb_070_var_24_2019-03-27-09-09-56_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_24_2019-03-27-09-09-56_test.npy
# cv       mean auc:0.52811
# var_25
# ***** seed 0 *****
# started at: 2019-03-27-09-10-15
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 217
# train fold 0 .train auc: 0.51703 val auc: 0.50499
# train fold 1 .train auc: 0.51800 val auc: 0.50582
# train fold 2 .train auc: 0.51811 val auc: 0.51194
# train fold 3 .train auc: 0.51788 val auc: 0.50351
# train fold 4 .train auc: 0.51666 val auc: 0.51555
# saving raw train prediction to: ../submissions/lgb_070_var_25_2019-03-27-09-10-15_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_25_2019-03-27-09-10-15_test.npy
# cv       mean auc:0.50730
# var_26
# ***** seed 0 *****
# started at: 2019-03-27-09-10-22
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 836
# train fold 0 .train auc: 0.56407 val auc: 0.55816
# train fold 1 .train auc: 0.56472 val auc: 0.55675
# train fold 2 .train auc: 0.56391 val auc: 0.55839
# train fold 3 .train auc: 0.56344 val auc: 0.56032
# train fold 4 .train auc: 0.56398 val auc: 0.55905
# saving raw train prediction to: ../submissions/lgb_070_var_26_2019-03-27-09-10-22_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_26_2019-03-27-09-10-22_test.npy
# cv       mean auc:0.55796
# var_27
# ***** seed 0 *****
# started at: 2019-03-27-09-10-42
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1
# train fold 0 .train auc: 0.50118 val auc: 0.50012
# train fold 1 .train auc: 0.50424 val auc: 0.50066
# train fold 2 .train auc: 0.50277 val auc: 0.49367
# train fold 3 .train auc: 0.50494 val auc: 0.49999
# train fold 4 .train auc: 0.50439 val auc: 0.49920
# saving raw train prediction to: ../submissions/lgb_070_var_27_2019-03-27-09-10-42_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_27_2019-03-27-09-10-42_test.npy
# cv       mean auc:0.49857
# var_28
# ***** seed 0 *****
# started at: 2019-03-27-09-10-45
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 351
# train fold 0 .train auc: 0.52904 val auc: 0.52314
# train fold 1 .train auc: 0.53239 val auc: 0.51588
# train fold 2 .train auc: 0.52947 val auc: 0.52791
# train fold 3 .train auc: 0.53015 val auc: 0.51980
# train fold 4 .train auc: 0.52975 val auc: 0.52267
# saving raw train prediction to: ../submissions/lgb_070_var_28_2019-03-27-09-10-45_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_28_2019-03-27-09-10-45_test.npy
# cv       mean auc:0.52083
# var_29
# ***** seed 0 *****
# started at: 2019-03-27-09-10-54
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 30
# train fold 0 .train auc: 0.50858 val auc: 0.50116
# train fold 1 .train auc: 0.50880 val auc: 0.49635
# train fold 2 .train auc: 0.50782 val auc: 0.50033
# train fold 3 .train auc: 0.50807 val auc: 0.50374
# train fold 4 .train auc: 0.51062 val auc: 0.50092
# saving raw train prediction to: ../submissions/lgb_070_var_29_2019-03-27-09-10-54_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_29_2019-03-27-09-10-54_test.npy
# cv       mean auc:0.49924
# var_30
# ***** seed 0 *****
# started at: 2019-03-27-09-10-58
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 0
# train fold 0 .train auc: 0.50391 val auc: 0.49096
# train fold 1 .train auc: 0.50541 val auc: 0.50160
# train fold 2 .train auc: 0.50272 val auc: 0.49196
# train fold 3 .train auc: 0.50340 val auc: 0.49288
# train fold 4 .train auc: 0.50334 val auc: 0.50050
# saving raw train prediction to: ../submissions/lgb_070_var_30_2019-03-27-09-10-58_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_30_2019-03-27-09-10-58_test.npy
# cv       mean auc:0.49967
# var_31
# ***** seed 0 *****
# started at: 2019-03-27-09-11-01
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 323
# train fold 0 .train auc: 0.53217 val auc: 0.52340
# train fold 1 .train auc: 0.53017 val auc: 0.52762
# train fold 2 .train auc: 0.53152 val auc: 0.52644
# train fold 3 .train auc: 0.53060 val auc: 0.52730
# train fold 4 .train auc: 0.53216 val auc: 0.52585
# saving raw train prediction to: ../submissions/lgb_070_var_31_2019-03-27-09-11-01_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_31_2019-03-27-09-11-01_test.npy
# cv       mean auc:0.52583
# var_32
# ***** seed 0 *****
# started at: 2019-03-27-09-11-10
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 824
# train fold 0 .train auc: 0.53600 val auc: 0.52884
# train fold 1 .train auc: 0.53522 val auc: 0.53007
# train fold 2 .train auc: 0.53614 val auc: 0.52625
# train fold 3 .train auc: 0.53700 val auc: 0.52318
# train fold 4 .train auc: 0.53578 val auc: 0.53177
# saving raw train prediction to: ../submissions/lgb_070_var_32_2019-03-27-09-11-10_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_32_2019-03-27-09-11-10_test.npy
# cv       mean auc:0.52772
# var_33
# ***** seed 0 *****
# started at: 2019-03-27-09-11-29
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 736
# train fold 0 .train auc: 0.54611 val auc: 0.53917
# train fold 1 .train auc: 0.54540 val auc: 0.54493
# train fold 2 .train auc: 0.54636 val auc: 0.53719
# train fold 3 .train auc: 0.54802 val auc: 0.53120
# train fold 4 .train auc: 0.54596 val auc: 0.54359
# saving raw train prediction to: ../submissions/lgb_070_var_33_2019-03-27-09-11-29_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_33_2019-03-27-09-11-29_test.npy
# cv       mean auc:0.53857
# var_34
# ***** seed 0 *****
# started at: 2019-03-27-09-11-45
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 362
# train fold 0 .train auc: 0.55085 val auc: 0.54079
# train fold 1 .train auc: 0.54973 val auc: 0.54658
# train fold 2 .train auc: 0.54862 val auc: 0.55264
# train fold 3 .train auc: 0.54879 val auc: 0.55039
# train fold 4 .train auc: 0.55187 val auc: 0.53966
# saving raw train prediction to: ../submissions/lgb_070_var_34_2019-03-27-09-11-45_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_34_2019-03-27-09-11-45_test.npy
# cv       mean auc:0.54489
# var_35
# ***** seed 0 *****
# started at: 2019-03-27-09-11-55
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 798
# train fold 0 .train auc: 0.54438 val auc: 0.53033
# train fold 1 .train auc: 0.54016 val auc: 0.54417
# train fold 2 .train auc: 0.54567 val auc: 0.52971
# train fold 3 .train auc: 0.54248 val auc: 0.54026
# train fold 4 .train auc: 0.54283 val auc: 0.53523
# saving raw train prediction to: ../submissions/lgb_070_var_35_2019-03-27-09-11-55_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_35_2019-03-27-09-11-55_test.npy
# cv       mean auc:0.53524
# var_36
# ***** seed 0 *****
# started at: 2019-03-27-09-12-14
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 767
# train fold 0 .train auc: 0.54351 val auc: 0.54186
# train fold 1 .train auc: 0.54346 val auc: 0.54047
# train fold 2 .train auc: 0.54549 val auc: 0.53078
# train fold 3 .train auc: 0.54438 val auc: 0.54058
# train fold 4 .train auc: 0.54342 val auc: 0.54042
# saving raw train prediction to: ../submissions/lgb_070_var_36_2019-03-27-09-12-14_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_36_2019-03-27-09-12-14_test.npy
# cv       mean auc:0.53797
# var_37
# ***** seed 0 *****
# started at: 2019-03-27-09-12-32
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 222
# train fold 0 .train auc: 0.51783 val auc: 0.51025
# train fold 1 .train auc: 0.51724 val auc: 0.49741
# train fold 2 .train auc: 0.51792 val auc: 0.50692
# train fold 3 .train auc: 0.51726 val auc: 0.50635
# train fold 4 .train auc: 0.51580 val auc: 0.51257
# saving raw train prediction to: ../submissions/lgb_070_var_37_2019-03-27-09-12-32_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_37_2019-03-27-09-12-32_test.npy
# cv       mean auc:0.50522
# var_38
# ***** seed 0 *****
# started at: 2019-03-27-09-12-39
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1
# train fold 0 .train auc: 0.50312 val auc: 0.49136
# train fold 1 .train auc: 0.50295 val auc: 0.50933
# train fold 2 .train auc: 0.50593 val auc: 0.49641
# train fold 3 .train auc: 0.50700 val auc: 0.49649
# train fold 4 .train auc: 0.50319 val auc: 0.50087
# saving raw train prediction to: ../submissions/lgb_070_var_38_2019-03-27-09-12-39_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_38_2019-03-27-09-12-39_test.npy
# cv       mean auc:0.49669
# var_39
# ***** seed 0 *****
# started at: 2019-03-27-09-12-42
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 126
# train fold 0 .train auc: 0.51505 val auc: 0.49718
# train fold 1 .train auc: 0.51542 val auc: 0.50905
# train fold 2 .train auc: 0.51613 val auc: 0.49835
# train fold 3 .train auc: 0.51417 val auc: 0.50271
# train fold 4 .train auc: 0.51424 val auc: 0.50811
# saving raw train prediction to: ../submissions/lgb_070_var_39_2019-03-27-09-12-42_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_39_2019-03-27-09-12-42_test.npy
# cv       mean auc:0.50279
# var_40
# ***** seed 0 *****
# started at: 2019-03-27-09-12-47
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 548
# train fold 0 .train auc: 0.55267 val auc: 0.54030
# train fold 1 .train auc: 0.54934 val auc: 0.55298
# train fold 2 .train auc: 0.54988 val auc: 0.54970
# train fold 3 .train auc: 0.55329 val auc: 0.53777
# train fold 4 .train auc: 0.55030 val auc: 0.55095
# saving raw train prediction to: ../submissions/lgb_070_var_40_2019-03-27-09-12-47_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_40_2019-03-27-09-12-47_test.npy
# cv       mean auc:0.54548
# var_41
# ***** seed 0 *****
# started at: 2019-03-27-09-13-00
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 53
# train fold 0 .train auc: 0.51339 val auc: 0.49859
# train fold 1 .train auc: 0.51342 val auc: 0.50060
# train fold 2 .train auc: 0.51116 val auc: 0.50223
# train fold 3 .train auc: 0.51212 val auc: 0.50429
# train fold 4 .train auc: 0.51194 val auc: 0.49799
# saving raw train prediction to: ../submissions/lgb_070_var_41_2019-03-27-09-13-00_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_41_2019-03-27-09-13-00_test.npy
# cv       mean auc:0.49960
# var_42
# ***** seed 0 *****
# started at: 2019-03-27-09-13-04
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 91
# train fold 0 .train auc: 0.51397 val auc: 0.50565
# train fold 1 .train auc: 0.51165 val auc: 0.50606
# train fold 2 .train auc: 0.51499 val auc: 0.50380
# train fold 3 .train auc: 0.51472 val auc: 0.50137
# train fold 4 .train auc: 0.51316 val auc: 0.50665
# saving raw train prediction to: ../submissions/lgb_070_var_42_2019-03-27-09-13-04_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_42_2019-03-27-09-13-04_test.npy
# cv       mean auc:0.50347
# var_43
# ***** seed 0 *****
# started at: 2019-03-27-09-13-08
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 240
# train fold 0 .train auc: 0.53173 val auc: 0.51621
# train fold 1 .train auc: 0.52930 val auc: 0.52739
# train fold 2 .train auc: 0.52965 val auc: 0.52270
# train fold 3 .train auc: 0.52816 val auc: 0.53040
# train fold 4 .train auc: 0.52955 val auc: 0.52585
# saving raw train prediction to: ../submissions/lgb_070_var_43_2019-03-27-09-13-08_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_43_2019-03-27-09-13-08_test.npy
# cv       mean auc:0.52382
# var_44
# ***** seed 0 *****
# started at: 2019-03-27-09-13-15
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 496
# train fold 0 .train auc: 0.54983 val auc: 0.55364
# train fold 1 .train auc: 0.55361 val auc: 0.53314
# train fold 2 .train auc: 0.55022 val auc: 0.54272
# train fold 3 .train auc: 0.55019 val auc: 0.54354
# train fold 4 .train auc: 0.55179 val auc: 0.54280
# saving raw train prediction to: ../submissions/lgb_070_var_44_2019-03-27-09-13-15_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_44_2019-03-27-09-13-15_test.npy
# cv       mean auc:0.54243
# var_45
# ***** seed 0 *****
# started at: 2019-03-27-09-13-28
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 744
# train fold 0 .train auc: 0.52971 val auc: 0.52227
# train fold 1 .train auc: 0.52741 val auc: 0.51820
# train fold 2 .train auc: 0.52897 val auc: 0.51475
# train fold 3 .train auc: 0.52907 val auc: 0.52010
# train fold 4 .train auc: 0.52949 val auc: 0.51541
# saving raw train prediction to: ../submissions/lgb_070_var_45_2019-03-27-09-13-28_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_45_2019-03-27-09-13-28_test.npy
# cv       mean auc:0.51770
# var_46
# ***** seed 0 *****
# started at: 2019-03-27-09-13-44
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 71
# train fold 0 .train auc: 0.51008 val auc: 0.50647
# train fold 1 .train auc: 0.51154 val auc: 0.49716
# train fold 2 .train auc: 0.51349 val auc: 0.49193
# train fold 3 .train auc: 0.51160 val auc: 0.49876
# train fold 4 .train auc: 0.51210 val auc: 0.50325
# saving raw train prediction to: ../submissions/lgb_070_var_46_2019-03-27-09-13-44_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_46_2019-03-27-09-13-44_test.npy
# cv       mean auc:0.49811
# var_47
# ***** seed 0 *****
# started at: 2019-03-27-09-13-49
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 230
# train fold 0 .train auc: 0.51703 val auc: 0.50639
# train fold 1 .train auc: 0.51663 val auc: 0.50810
# train fold 2 .train auc: 0.51617 val auc: 0.51261
# train fold 3 .train auc: 0.51682 val auc: 0.49871
# train fold 4 .train auc: 0.51693 val auc: 0.50547
# saving raw train prediction to: ../submissions/lgb_070_var_47_2019-03-27-09-13-49_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_47_2019-03-27-09-13-49_test.npy
# cv       mean auc:0.50594
# var_48
# ***** seed 0 *****
# started at: 2019-03-27-09-13-55
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 493
# train fold 0 .train auc: 0.53732 val auc: 0.53700
# train fold 1 .train auc: 0.53823 val auc: 0.52897
# train fold 2 .train auc: 0.53810 val auc: 0.53140
# train fold 3 .train auc: 0.53731 val auc: 0.53533
# train fold 4 .train auc: 0.53782 val auc: 0.53392
# saving raw train prediction to: ../submissions/lgb_070_var_48_2019-03-27-09-13-55_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_48_2019-03-27-09-13-55_test.npy
# cv       mean auc:0.53253
# var_49
# ***** seed 0 *****
# started at: 2019-03-27-09-14-08
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 871
# train fold 0 .train auc: 0.53760 val auc: 0.52463
# train fold 1 .train auc: 0.53739 val auc: 0.52320
# train fold 2 .train auc: 0.53688 val auc: 0.52899
# train fold 3 .train auc: 0.53575 val auc: 0.53126
# train fold 4 .train auc: 0.53517 val auc: 0.53511
# saving raw train prediction to: ../submissions/lgb_070_var_49_2019-03-27-09-14-08_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_49_2019-03-27-09-14-08_test.npy
# cv       mean auc:0.52783
# var_50
# ***** seed 0 *****
# started at: 2019-03-27-09-14-27
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 253
# train fold 0 .train auc: 0.52121 val auc: 0.51657
# train fold 1 .train auc: 0.52054 val auc: 0.51737
# train fold 2 .train auc: 0.52078 val auc: 0.51795
# train fold 3 .train auc: 0.52211 val auc: 0.51406
# train fold 4 .train auc: 0.52290 val auc: 0.50762
# saving raw train prediction to: ../submissions/lgb_070_var_50_2019-03-27-09-14-27_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_50_2019-03-27-09-14-27_test.npy
# cv       mean auc:0.51366
# var_51
# ***** seed 0 *****
# started at: 2019-03-27-09-14-34
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1317
# train fold 0 .train auc: 0.53795 val auc: 0.52763
# train fold 1 .train auc: 0.53731 val auc: 0.52565
# train fold 2 .train auc: 0.53802 val auc: 0.52466
# train fold 3 .train auc: 0.53794 val auc: 0.52748
# train fold 4 .train auc: 0.53883 val auc: 0.52345
# saving raw train prediction to: ../submissions/lgb_070_var_51_2019-03-27-09-14-34_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_51_2019-03-27-09-14-34_test.npy
# cv       mean auc:0.52544
# var_52
# ***** seed 0 *****
# started at: 2019-03-27-09-15-02
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 386
# train fold 0 .train auc: 0.53547 val auc: 0.52449
# train fold 1 .train auc: 0.53459 val auc: 0.52846
# train fold 2 .train auc: 0.53363 val auc: 0.53281
# train fold 3 .train auc: 0.53376 val auc: 0.53206
# train fold 4 .train auc: 0.53481 val auc: 0.52347
# saving raw train prediction to: ../submissions/lgb_070_var_52_2019-03-27-09-15-02_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_52_2019-03-27-09-15-02_test.npy
# cv       mean auc:0.52736
# var_53
# ***** seed 0 *****
# started at: 2019-03-27-09-15-12
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 457
# train fold 0 .train auc: 0.55999 val auc: 0.55241
# train fold 1 .train auc: 0.55945 val auc: 0.55609
# train fold 2 .train auc: 0.55976 val auc: 0.55375
# train fold 3 .train auc: 0.55694 val auc: 0.56108
# train fold 4 .train auc: 0.56010 val auc: 0.54981
# saving raw train prediction to: ../submissions/lgb_070_var_53_2019-03-27-09-15-12_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_53_2019-03-27-09-15-12_test.npy
# cv       mean auc:0.55343
# var_54
# ***** seed 0 *****
# started at: 2019-03-27-09-15-24
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 637
# train fold 0 .train auc: 0.52860 val auc: 0.51168
# train fold 1 .train auc: 0.52747 val auc: 0.51828
# train fold 2 .train auc: 0.52701 val auc: 0.52423
# train fold 3 .train auc: 0.52672 val auc: 0.52635
# train fold 4 .train auc: 0.52923 val auc: 0.51223
# saving raw train prediction to: ../submissions/lgb_070_var_54_2019-03-27-09-15-24_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_54_2019-03-27-09-15-24_test.npy
# cv       mean auc:0.51785
# var_55
# ***** seed 0 *****
# started at: 2019-03-27-09-15-40
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 372
# train fold 0 .train auc: 0.52075 val auc: 0.52172
# train fold 1 .train auc: 0.52404 val auc: 0.51135
# train fold 2 .train auc: 0.52261 val auc: 0.50843
# train fold 3 .train auc: 0.52211 val auc: 0.51195
# train fold 4 .train auc: 0.52305 val auc: 0.51994
# saving raw train prediction to: ../submissions/lgb_070_var_55_2019-03-27-09-15-40_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_55_2019-03-27-09-15-40_test.npy
# cv       mean auc:0.51331
# var_56
# ***** seed 0 *****
# started at: 2019-03-27-09-15-49
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 621
# train fold 0 .train auc: 0.53528 val auc: 0.52202
# train fold 1 .train auc: 0.53546 val auc: 0.52763
# train fold 2 .train auc: 0.53396 val auc: 0.53112
# train fold 3 .train auc: 0.53490 val auc: 0.52796
# train fold 4 .train auc: 0.53337 val auc: 0.53482
# saving raw train prediction to: ../submissions/lgb_070_var_56_2019-03-27-09-15-49_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_56_2019-03-27-09-15-49_test.npy
# cv       mean auc:0.52816
# var_57
# ***** seed 0 *****
# started at: 2019-03-27-09-16-04
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 224
# train fold 0 .train auc: 0.52041 val auc: 0.51235
# train fold 1 .train auc: 0.51812 val auc: 0.51797
# train fold 2 .train auc: 0.52162 val auc: 0.50517
# train fold 3 .train auc: 0.52072 val auc: 0.51100
# train fold 4 .train auc: 0.51896 val auc: 0.51742
# saving raw train prediction to: ../submissions/lgb_070_var_57_2019-03-27-09-16-04_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_57_2019-03-27-09-16-04_test.npy
# cv       mean auc:0.51207
# var_58
# ***** seed 0 *****
# started at: 2019-03-27-09-16-11
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 405
# train fold 0 .train auc: 0.53438 val auc: 0.51802
# train fold 1 .train auc: 0.53196 val auc: 0.52773
# train fold 2 .train auc: 0.52964 val auc: 0.53559
# train fold 3 .train auc: 0.53319 val auc: 0.52339
# train fold 4 .train auc: 0.53124 val auc: 0.52791
# saving raw train prediction to: ../submissions/lgb_070_var_58_2019-03-27-09-16-11_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_58_2019-03-27-09-16-11_test.npy
# cv       mean auc:0.52560
# var_59
# ***** seed 0 *****
# started at: 2019-03-27-09-16-22
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 226
# train fold 0 .train auc: 0.51558 val auc: 0.50425
# train fold 1 .train auc: 0.51644 val auc: 0.50546
# train fold 2 .train auc: 0.51722 val auc: 0.50341
# train fold 3 .train auc: 0.51702 val auc: 0.51229
# train fold 4 .train auc: 0.51555 val auc: 0.50886
# saving raw train prediction to: ../submissions/lgb_070_var_59_2019-03-27-09-16-22_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_59_2019-03-27-09-16-22_test.npy
# cv       mean auc:0.50628
# var_60
# ***** seed 0 *****
# started at: 2019-03-27-09-16-29
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 187
# train fold 0 .train auc: 0.51750 val auc: 0.50121
# train fold 1 .train auc: 0.51394 val auc: 0.51219
# train fold 2 .train auc: 0.51686 val auc: 0.50819
# train fold 3 .train auc: 0.51514 val auc: 0.51162
# train fold 4 .train auc: 0.51461 val auc: 0.51504
# saving raw train prediction to: ../submissions/lgb_070_var_60_2019-03-27-09-16-29_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_60_2019-03-27-09-16-29_test.npy
# cv       mean auc:0.50881
# var_61
# ***** seed 0 *****
# started at: 2019-03-27-09-16-35
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 515
# train fold 0 .train auc: 0.51941 val auc: 0.50223
# train fold 1 .train auc: 0.52299 val auc: 0.50510
# train fold 2 .train auc: 0.52019 val auc: 0.50872
# train fold 3 .train auc: 0.52111 val auc: 0.50134
# train fold 4 .train auc: 0.52251 val auc: 0.50767
# saving raw train prediction to: ../submissions/lgb_070_var_61_2019-03-27-09-16-35_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_61_2019-03-27-09-16-35_test.npy
# cv       mean auc:0.50473
# var_62
# ***** seed 0 *****
# started at: 2019-03-27-09-16-48
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 377
# train fold 0 .train auc: 0.52204 val auc: 0.50916
# train fold 1 .train auc: 0.52115 val auc: 0.51380
# train fold 2 .train auc: 0.52117 val auc: 0.51528
# train fold 3 .train auc: 0.52277 val auc: 0.50463
# train fold 4 .train auc: 0.52103 val auc: 0.51263
# saving raw train prediction to: ../submissions/lgb_070_var_62_2019-03-27-09-16-48_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_62_2019-03-27-09-16-48_test.npy
# cv       mean auc:0.51044
# var_63
# ***** seed 0 *****
# started at: 2019-03-27-09-16-58
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 695
# train fold 0 .train auc: 0.52588 val auc: 0.51339
# train fold 1 .train auc: 0.52420 val auc: 0.50993
# train fold 2 .train auc: 0.52487 val auc: 0.51058
# train fold 3 .train auc: 0.52492 val auc: 0.51312
# train fold 4 .train auc: 0.52537 val auc: 0.51392
# saving raw train prediction to: ../submissions/lgb_070_var_63_2019-03-27-09-16-58_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_63_2019-03-27-09-16-58_test.npy
# cv       mean auc:0.51189
# var_64
# ***** seed 0 *****
# started at: 2019-03-27-09-17-14
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 248
# train fold 0 .train auc: 0.51882 val auc: 0.51240
# train fold 1 .train auc: 0.51727 val auc: 0.51557
# train fold 2 .train auc: 0.52055 val auc: 0.50653
# train fold 3 .train auc: 0.51736 val auc: 0.51353
# train fold 4 .train auc: 0.51936 val auc: 0.50733
# saving raw train prediction to: ../submissions/lgb_070_var_64_2019-03-27-09-17-14_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_64_2019-03-27-09-17-14_test.npy
# cv       mean auc:0.50992
# var_65
# ***** seed 0 *****
# started at: 2019-03-27-09-17-22
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 476
# train fold 0 .train auc: 0.52089 val auc: 0.50829
# train fold 1 .train auc: 0.52115 val auc: 0.50695
# train fold 2 .train auc: 0.52071 val auc: 0.50898
# train fold 3 .train auc: 0.51950 val auc: 0.51667
# train fold 4 .train auc: 0.52059 val auc: 0.51121
# saving raw train prediction to: ../submissions/lgb_070_var_65_2019-03-27-09-17-22_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_65_2019-03-27-09-17-22_test.npy
# cv       mean auc:0.50960
# var_66
# ***** seed 0 *****
# started at: 2019-03-27-09-17-34
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 303
# train fold 0 .train auc: 0.52641 val auc: 0.52006
# train fold 1 .train auc: 0.52660 val auc: 0.52047
# train fold 2 .train auc: 0.52602 val auc: 0.51930
# train fold 3 .train auc: 0.52720 val auc: 0.51566
# train fold 4 .train auc: 0.52578 val auc: 0.52819
# saving raw train prediction to: ../submissions/lgb_070_var_66_2019-03-27-09-17-34_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_66_2019-03-27-09-17-34_test.npy
# cv       mean auc:0.52005
# var_67
# ***** seed 0 *****
# started at: 2019-03-27-09-17-43
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 907
# train fold 0 .train auc: 0.55027 val auc: 0.54106
# train fold 1 .train auc: 0.55003 val auc: 0.53958
# train fold 2 .train auc: 0.54886 val auc: 0.54614
# train fold 3 .train auc: 0.54772 val auc: 0.55049
# train fold 4 .train auc: 0.55045 val auc: 0.54258
# saving raw train prediction to: ../submissions/lgb_070_var_67_2019-03-27-09-17-43_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_67_2019-03-27-09-17-43_test.npy
# cv       mean auc:0.54337
# var_68
# ***** seed 0 *****
# started at: 2019-03-27-09-18-03
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 194
# train fold 0 .train auc: 0.51657 val auc: 0.51625
# train fold 1 .train auc: 0.51656 val auc: 0.50790
# train fold 2 .train auc: 0.51735 val auc: 0.50758
# train fold 3 .train auc: 0.51750 val auc: 0.50894
# train fold 4 .train auc: 0.52030 val auc: 0.50265
# saving raw train prediction to: ../submissions/lgb_070_var_68_2019-03-27-09-18-03_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_68_2019-03-27-09-18-03_test.npy
# cv       mean auc:0.50771
# var_69
# ***** seed 0 *****
# started at: 2019-03-27-09-18-09
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 239
# train fold 0 .train auc: 0.51682 val auc: 0.50554
# train fold 1 .train auc: 0.51616 val auc: 0.50791
# train fold 2 .train auc: 0.51488 val auc: 0.51086
# train fold 3 .train auc: 0.51519 val auc: 0.50887
# train fold 4 .train auc: 0.51563 val auc: 0.51166
# saving raw train prediction to: ../submissions/lgb_070_var_69_2019-03-27-09-18-09_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_69_2019-03-27-09-18-09_test.npy
# cv       mean auc:0.50831
# var_70
# ***** seed 0 *****
# started at: 2019-03-27-09-18-16
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 527
# train fold 0 .train auc: 0.53358 val auc: 0.52582
# train fold 1 .train auc: 0.53238 val auc: 0.53338
# train fold 2 .train auc: 0.53426 val auc: 0.52210
# train fold 3 .train auc: 0.53416 val auc: 0.52105
# train fold 4 .train auc: 0.53397 val auc: 0.52664
# saving raw train prediction to: ../submissions/lgb_070_var_70_2019-03-27-09-18-16_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_70_2019-03-27-09-18-16_test.npy
# cv       mean auc:0.52479
# var_71
# ***** seed 0 *****
# started at: 2019-03-27-09-18-29
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 434
# train fold 0 .train auc: 0.53548 val auc: 0.52933
# train fold 1 .train auc: 0.53541 val auc: 0.53283
# train fold 2 .train auc: 0.53519 val auc: 0.53126
# train fold 3 .train auc: 0.53479 val auc: 0.53276
# train fold 4 .train auc: 0.53653 val auc: 0.52688
# saving raw train prediction to: ../submissions/lgb_070_var_71_2019-03-27-09-18-29_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_71_2019-03-27-09-18-29_test.npy
# cv       mean auc:0.52967
# var_72
# ***** seed 0 *****
# started at: 2019-03-27-09-18-40
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 320
# train fold 0 .train auc: 0.51827 val auc: 0.51845
# train fold 1 .train auc: 0.51980 val auc: 0.50938
# train fold 2 .train auc: 0.51940 val auc: 0.51230
# train fold 3 .train auc: 0.51973 val auc: 0.51060
# train fold 4 .train auc: 0.52146 val auc: 0.50542
# saving raw train prediction to: ../submissions/lgb_070_var_72_2019-03-27-09-18-40_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_72_2019-03-27-09-18-40_test.npy
# cv       mean auc:0.50981
# var_73
# ***** seed 0 *****
# started at: 2019-03-27-09-18-49
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 313
# train fold 0 .train auc: 0.51769 val auc: 0.50847
# train fold 1 .train auc: 0.51601 val auc: 0.50550
# train fold 2 .train auc: 0.51896 val auc: 0.51468
# train fold 3 .train auc: 0.51995 val auc: 0.49890
# train fold 4 .train auc: 0.52032 val auc: 0.49764
# saving raw train prediction to: ../submissions/lgb_070_var_73_2019-03-27-09-18-49_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_73_2019-03-27-09-18-49_test.npy
# cv       mean auc:0.50363
# var_74
# ***** seed 0 *****
# started at: 2019-03-27-09-18-57
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 623
# train fold 0 .train auc: 0.52865 val auc: 0.52076
# train fold 1 .train auc: 0.52634 val auc: 0.52592
# train fold 2 .train auc: 0.52621 val auc: 0.52056
# train fold 3 .train auc: 0.52800 val auc: 0.51994
# train fold 4 .train auc: 0.52874 val auc: 0.51626
# saving raw train prediction to: ../submissions/lgb_070_var_74_2019-03-27-09-18-57_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_74_2019-03-27-09-18-57_test.npy
# cv       mean auc:0.52002
# var_75
# ***** seed 0 *****
# started at: 2019-03-27-09-19-12
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 852
# train fold 0 .train auc: 0.54432 val auc: 0.53519
# train fold 1 .train auc: 0.54439 val auc: 0.53474
# train fold 2 .train auc: 0.54362 val auc: 0.53994
# train fold 3 .train auc: 0.54445 val auc: 0.53122
# train fold 4 .train auc: 0.54315 val auc: 0.54378
# saving raw train prediction to: ../submissions/lgb_070_var_75_2019-03-27-09-19-12_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_75_2019-03-27-09-19-12_test.npy
# cv       mean auc:0.53674
# var_76
# ***** seed 0 *****
# started at: 2019-03-27-09-19-31
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1274
# train fold 0 .train auc: 0.56621 val auc: 0.56381
# train fold 1 .train auc: 0.56782 val auc: 0.55390
# train fold 2 .train auc: 0.56712 val auc: 0.56030
# train fold 3 .train auc: 0.56607 val auc: 0.56283
# train fold 4 .train auc: 0.56621 val auc: 0.56287
# saving raw train prediction to: ../submissions/lgb_070_var_76_2019-03-27-09-19-31_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_76_2019-03-27-09-19-31_test.npy
# cv       mean auc:0.56047
# var_77
# ***** seed 0 *****
# started at: 2019-03-27-09-19-59
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 316
# train fold 0 .train auc: 0.52221 val auc: 0.51318
# train fold 1 .train auc: 0.52286 val auc: 0.51527
# train fold 2 .train auc: 0.52251 val auc: 0.51476
# train fold 3 .train auc: 0.52319 val auc: 0.51070
# train fold 4 .train auc: 0.52256 val auc: 0.51350
# saving raw train prediction to: ../submissions/lgb_070_var_77_2019-03-27-09-19-59_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_77_2019-03-27-09-19-59_test.npy
# cv       mean auc:0.51285
# var_78
# ***** seed 0 *****
# started at: 2019-03-27-09-20-08
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 578
# train fold 0 .train auc: 0.54601 val auc: 0.55046
# train fold 1 .train auc: 0.54989 val auc: 0.53177
# train fold 2 .train auc: 0.54677 val auc: 0.54422
# train fold 3 .train auc: 0.54718 val auc: 0.54609
# train fold 4 .train auc: 0.54957 val auc: 0.53461
# saving raw train prediction to: ../submissions/lgb_070_var_78_2019-03-27-09-20-08_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_78_2019-03-27-09-20-08_test.npy
# cv       mean auc:0.54075
# var_79
# ***** seed 0 *****
# started at: 2019-03-27-09-20-22
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 108
# train fold 0 .train auc: 0.50880 val auc: 0.50272
# train fold 1 .train auc: 0.51447 val auc: 0.49767
# train fold 2 .train auc: 0.51162 val auc: 0.50405
# train fold 3 .train auc: 0.51494 val auc: 0.49840
# train fold 4 .train auc: 0.51120 val auc: 0.50791
# saving raw train prediction to: ../submissions/lgb_070_var_79_2019-03-27-09-20-22_train.npy
# ...
# train fold 4 .train auc: 0.54248 val auc: 0.54521
# saving raw train prediction to: ../submissions/lgb_070_var_173_2019-03-27-09-43-40_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_173_2019-03-27-09-43-40_test.npy
# cv       mean auc:0.53836
# var_174
# ***** seed 0 *****
# started at: 2019-03-27-09-44-00
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 658
# train fold 0 .train auc: 0.55741 val auc: 0.55635
# train fold 1 .train auc: 0.55870 val auc: 0.55178
# train fold 2 .train auc: 0.55910 val auc: 0.55031
# train fold 3 .train auc: 0.55803 val auc: 0.55536
# train fold 4 .train auc: 0.55708 val auc: 0.55721
# saving raw train prediction to: ../submissions/lgb_070_var_174_2019-03-27-09-44-00_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_174_2019-03-27-09-44-00_test.npy
# cv       mean auc:0.55379
# var_175
# ***** seed 0 *****
# started at: 2019-03-27-09-44-21
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 343
# train fold 0 .train auc: 0.52919 val auc: 0.51674
# train fold 1 .train auc: 0.52702 val auc: 0.52200
# train fold 2 .train auc: 0.52899 val auc: 0.51883
# train fold 3 .train auc: 0.52878 val auc: 0.51778
# train fold 4 .train auc: 0.52532 val auc: 0.52692
# saving raw train prediction to: ../submissions/lgb_070_var_175_2019-03-27-09-44-21_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_175_2019-03-27-09-44-21_test.npy
# cv       mean auc:0.51954
# var_176
# ***** seed 0 *****
# started at: 2019-03-27-09-44-35
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 159
# train fold 0 .train auc: 0.51566 val auc: 0.49860
# train fold 1 .train auc: 0.51470 val auc: 0.50388
# train fold 2 .train auc: 0.51516 val auc: 0.50226
# train fold 3 .train auc: 0.51492 val auc: 0.50601
# train fold 4 .train auc: 0.51639 val auc: 0.51428
# saving raw train prediction to: ../submissions/lgb_070_var_176_2019-03-27-09-44-35_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_176_2019-03-27-09-44-35_test.npy
# cv       mean auc:0.50415
# var_177
# ***** seed 0 *****
# started at: 2019-03-27-09-44-43
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 577
# train fold 0 .train auc: 0.54126 val auc: 0.53762
# train fold 1 .train auc: 0.54381 val auc: 0.53132
# train fold 2 .train auc: 0.54328 val auc: 0.53149
# train fold 3 .train auc: 0.53987 val auc: 0.53952
# train fold 4 .train auc: 0.54234 val auc: 0.53646
# saving raw train prediction to: ../submissions/lgb_070_var_177_2019-03-27-09-44-43_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_177_2019-03-27-09-44-43_test.npy
# cv       mean auc:0.53454
# var_178
# ***** seed 0 *****
# started at: 2019-03-27-09-45-02
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1093
# train fold 0 .train auc: 0.53135 val auc: 0.52371
# train fold 1 .train auc: 0.53331 val auc: 0.51424
# train fold 2 .train auc: 0.53129 val auc: 0.51993
# train fold 3 .train auc: 0.53187 val auc: 0.51751
# train fold 4 .train auc: 0.52920 val auc: 0.52453
# saving raw train prediction to: ../submissions/lgb_070_var_178_2019-03-27-09-45-02_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_178_2019-03-27-09-45-02_test.npy
# cv       mean auc:0.51978
# var_179
# ***** seed 0 *****
# started at: 2019-03-27-09-45-34
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 837
# train fold 0 .train auc: 0.55021 val auc: 0.54993
# train fold 1 .train auc: 0.55517 val auc: 0.52797
# train fold 2 .train auc: 0.55087 val auc: 0.54576
# train fold 3 .train auc: 0.55040 val auc: 0.55000
# train fold 4 .train auc: 0.55213 val auc: 0.54383
# saving raw train prediction to: ../submissions/lgb_070_var_179_2019-03-27-09-45-34_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_179_2019-03-27-09-45-34_test.npy
# cv       mean auc:0.54285
# var_180
# ***** seed 0 *****
# started at: 2019-03-27-09-46-01
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 628
# train fold 0 .train auc: 0.53588 val auc: 0.52988
# train fold 1 .train auc: 0.53590 val auc: 0.52650
# train fold 2 .train auc: 0.53565 val auc: 0.52445
# train fold 3 .train auc: 0.53587 val auc: 0.52746
# train fold 4 .train auc: 0.53578 val auc: 0.52851
# saving raw train prediction to: ../submissions/lgb_070_var_180_2019-03-27-09-46-01_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_180_2019-03-27-09-46-01_test.npy
# cv       mean auc:0.52678
# var_181
# ***** seed 0 *****
# started at: 2019-03-27-09-46-21
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 581
# train fold 0 .train auc: 0.52519 val auc: 0.51417
# train fold 1 .train auc: 0.52291 val auc: 0.51708
# train fold 2 .train auc: 0.52479 val auc: 0.51096
# train fold 3 .train auc: 0.52508 val auc: 0.51298
# train fold 4 .train auc: 0.52424 val auc: 0.51637
# saving raw train prediction to: ../submissions/lgb_070_var_181_2019-03-27-09-46-21_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_181_2019-03-27-09-46-21_test.npy
# cv       mean auc:0.51326
# var_182
# ***** seed 0 *****
# started at: 2019-03-27-09-46-41
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 316
# train fold 0 .train auc: 0.51634 val auc: 0.49889
# train fold 1 .train auc: 0.51483 val auc: 0.50751
# train fold 2 .train auc: 0.51630 val auc: 0.50059
# train fold 3 .train auc: 0.51563 val auc: 0.50608
# train fold 4 .train auc: 0.51679 val auc: 0.50521
# saving raw train prediction to: ../submissions/lgb_070_var_182_2019-03-27-09-46-41_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_182_2019-03-27-09-46-41_test.npy
# cv       mean auc:0.50280
# var_183
# ***** seed 0 *****
# started at: 2019-03-27-09-46-53
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 69
# train fold 0 .train auc: 0.51098 val auc: 0.49926
# train fold 1 .train auc: 0.50944 val auc: 0.49821
# train fold 2 .train auc: 0.51165 val auc: 0.50088
# train fold 3 .train auc: 0.51406 val auc: 0.50251
# train fold 4 .train auc: 0.51078 val auc: 0.50260
# saving raw train prediction to: ../submissions/lgb_070_var_183_2019-03-27-09-46-53_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_183_2019-03-27-09-46-53_test.npy
# cv       mean auc:0.50031
# var_184
# ***** seed 0 *****
# started at: 2019-03-27-09-46-59
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 849
# train fold 0 .train auc: 0.55423 val auc: 0.54718
# train fold 1 .train auc: 0.55476 val auc: 0.54656
# train fold 2 .train auc: 0.55255 val auc: 0.55457
# train fold 3 .train auc: 0.55332 val auc: 0.55044
# train fold 4 .train auc: 0.55479 val auc: 0.54437
# saving raw train prediction to: ../submissions/lgb_070_var_184_2019-03-27-09-46-59_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_184_2019-03-27-09-46-59_test.npy
# cv       mean auc:0.54826
# var_185
# ***** seed 0 *****
# started at: 2019-03-27-09-47-26
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1
# train fold 0 .train auc: 0.50169 val auc: 0.50329
# train fold 1 .train auc: 0.50343 val auc: 0.50376
# train fold 2 .train auc: 0.50110 val auc: 0.49547
# train fold 3 .train auc: 0.50167 val auc: 0.49312
# train fold 4 .train auc: 0.50328 val auc: 0.49959
# saving raw train prediction to: ../submissions/lgb_070_var_185_2019-03-27-09-47-26_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_185_2019-03-27-09-47-26_test.npy
# cv       mean auc:0.49780
# var_186
# ***** seed 0 *****
# started at: 2019-03-27-09-47-30
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 503
# train fold 0 .train auc: 0.53248 val auc: 0.53455
# train fold 1 .train auc: 0.53446 val auc: 0.52730
# train fold 2 .train auc: 0.53556 val auc: 0.52737
# train fold 3 .train auc: 0.53595 val auc: 0.52510
# train fold 4 .train auc: 0.53403 val auc: 0.52820
# saving raw train prediction to: ../submissions/lgb_070_var_186_2019-03-27-09-47-30_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_186_2019-03-27-09-47-30_test.npy
# cv       mean auc:0.52784
# var_187
# ***** seed 0 *****
# started at: 2019-03-27-09-47-47
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 387
# train fold 0 .train auc: 0.52241 val auc: 0.51510
# train fold 1 .train auc: 0.52149 val auc: 0.51393
# train fold 2 .train auc: 0.52276 val auc: 0.51499
# train fold 3 .train auc: 0.52253 val auc: 0.50950
# train fold 4 .train auc: 0.52117 val auc: 0.50965
# saving raw train prediction to: ../submissions/lgb_070_var_187_2019-03-27-09-47-47_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_187_2019-03-27-09-47-47_test.npy
# cv       mean auc:0.51233
# var_188
# ***** seed 0 *****
# started at: 2019-03-27-09-48-00
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 592
# train fold 0 .train auc: 0.53543 val auc: 0.54310
# train fold 1 .train auc: 0.53788 val auc: 0.52871
# train fold 2 .train auc: 0.53797 val auc: 0.52912
# train fold 3 .train auc: 0.53627 val auc: 0.53336
# train fold 4 .train auc: 0.53918 val auc: 0.52301
# saving raw train prediction to: ../submissions/lgb_070_var_188_2019-03-27-09-48-00_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_188_2019-03-27-09-48-00_test.npy
# cv       mean auc:0.53075
# var_189
# ***** seed 0 *****
# started at: 2019-03-27-09-48-20
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 123
# train fold 0 .train auc: 0.51498 val auc: 0.50701
# train fold 1 .train auc: 0.51635 val auc: 0.50497
# train fold 2 .train auc: 0.51359 val auc: 0.50712
# train fold 3 .train auc: 0.51366 val auc: 0.50345
# train fold 4 .train auc: 0.51740 val auc: 0.50495
# saving raw train prediction to: ../submissions/lgb_070_var_189_2019-03-27-09-48-20_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_189_2019-03-27-09-48-20_test.npy
# cv       mean auc:0.50526
# var_190
# ***** seed 0 *****
# started at: 2019-03-27-09-48-27
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1166
# train fold 0 .train auc: 0.55752 val auc: 0.55124
# train fold 1 .train auc: 0.55904 val auc: 0.54892
# train fold 2 .train auc: 0.55885 val auc: 0.55087
# train fold 3 .train auc: 0.55759 val auc: 0.55312
# train fold 4 .train auc: 0.55733 val auc: 0.55292
# saving raw train prediction to: ../submissions/lgb_070_var_190_2019-03-27-09-48-27_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_190_2019-03-27-09-48-27_test.npy
# cv       mean auc:0.55097
# var_191
# ***** seed 0 *****
# started at: 2019-03-27-09-49-02
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 1076
# train fold 0 .train auc: 0.55164 val auc: 0.54089
# train fold 1 .train auc: 0.54915 val auc: 0.55222
# train fold 2 .train auc: 0.54883 val auc: 0.55085
# train fold 3 .train auc: 0.55271 val auc: 0.53676
# train fold 4 .train auc: 0.55161 val auc: 0.53999
# saving raw train prediction to: ../submissions/lgb_070_var_191_2019-03-27-09-49-02_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_191_2019-03-27-09-49-02_test.npy
# cv       mean auc:0.54387
# var_192
# ***** seed 0 *****
# started at: 2019-03-27-09-49-35
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 440
# train fold 0 .train auc: 0.54779 val auc: 0.54244
# train fold 1 .train auc: 0.54776 val auc: 0.54464
# train fold 2 .train auc: 0.54977 val auc: 0.53685
# train fold 3 .train auc: 0.54602 val auc: 0.55439
# train fold 4 .train auc: 0.54825 val auc: 0.54017
# saving raw train prediction to: ../submissions/lgb_070_var_192_2019-03-27-09-49-35_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_192_2019-03-27-09-49-35_test.npy
# cv       mean auc:0.54266
# var_193
# ***** seed 0 *****
# started at: 2019-03-27-09-49-52
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 351
# train fold 0 .train auc: 0.52427 val auc: 0.51524
# train fold 1 .train auc: 0.52175 val auc: 0.51696
# train fold 2 .train auc: 0.52296 val auc: 0.51667
# train fold 3 .train auc: 0.52335 val auc: 0.51054
# train fold 4 .train auc: 0.52294 val auc: 0.51507
# saving raw train prediction to: ../submissions/lgb_070_var_193_2019-03-27-09-49-52_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_193_2019-03-27-09-49-52_test.npy
# cv       mean auc:0.51409
# var_194
# ***** seed 0 *****
# started at: 2019-03-27-09-50-05
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 349
# train fold 0 .train auc: 0.52495 val auc: 0.52460
# train fold 1 .train auc: 0.52521 val auc: 0.52123
# train fold 2 .train auc: 0.52680 val auc: 0.51592
# train fold 3 .train auc: 0.52669 val auc: 0.51057
# train fold 4 .train auc: 0.52555 val auc: 0.52123
# saving raw train prediction to: ../submissions/lgb_070_var_194_2019-03-27-09-50-05_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_194_2019-03-27-09-50-05_test.npy
# cv       mean auc:0.51763
# var_195
# ***** seed 0 *****
# started at: 2019-03-27-09-50-18
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 499
# train fold 0 .train auc: 0.53480 val auc: 0.51866
# train fold 1 .train auc: 0.53255 val auc: 0.52592
# train fold 2 .train auc: 0.53449 val auc: 0.52285
# train fold 3 .train auc: 0.53318 val auc: 0.52419
# train fold 4 .train auc: 0.53195 val auc: 0.53193
# saving raw train prediction to: ../submissions/lgb_070_var_195_2019-03-27-09-50-18_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_195_2019-03-27-09-50-18_test.npy
# cv       mean auc:0.52442
# var_196
# ***** seed 0 *****
# started at: 2019-03-27-09-50-36
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 793
# train fold 0 .train auc: 0.53221 val auc: 0.51372
# train fold 1 .train auc: 0.53056 val auc: 0.52543
# train fold 2 .train auc: 0.52900 val auc: 0.52710
# train fold 3 .train auc: 0.53210 val auc: 0.51752
# train fold 4 .train auc: 0.52999 val auc: 0.52296
# saving raw train prediction to: ../submissions/lgb_070_var_196_2019-03-27-09-50-36_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_196_2019-03-27-09-50-36_test.npy
# cv       mean auc:0.52057
# var_197
# ***** seed 0 *****
# started at: 2019-03-27-09-51-01
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 986
# train fold 0 .train auc: 0.53910 val auc: 0.52691
# train fold 1 .train auc: 0.53878 val auc: 0.53362
# train fold 2 .train auc: 0.53832 val auc: 0.53145
# train fold 3 .train auc: 0.53721 val auc: 0.53372
# train fold 4 .train auc: 0.53960 val auc: 0.52371
# saving raw train prediction to: ../submissions/lgb_070_var_197_2019-03-27-09-51-01_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_197_2019-03-27-09-51-01_test.npy
# cv       mean auc:0.52936
# var_198
# ***** seed 0 *****
# started at: 2019-03-27-09-51-33
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 849
# train fold 0 .train auc: 0.55538 val auc: 0.55376
# train fold 1 .train auc: 0.55661 val auc: 0.54547
# train fold 2 .train auc: 0.55691 val auc: 0.54543
# train fold 3 .train auc: 0.55753 val auc: 0.54629
# train fold 4 .train auc: 0.55486 val auc: 0.55370
# saving raw train prediction to: ../submissions/lgb_070_var_198_2019-03-27-09-51-33_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_198_2019-03-27-09-51-33_test.npy
# cv       mean auc:0.54833
# var_199
# ***** seed 0 *****
# started at: 2019-03-27-09-51-59
# num bagging seeds: 1
# (200000, 2) (200000, 2)
# nfold 5
# num features: 2
# best_round: 578
# train fold 0 .train auc: 0.53185 val auc: 0.52617
# train fold 1 .train auc: 0.53305 val auc: 0.52686
# train fold 2 .train auc: 0.53332 val auc: 0.52105
# train fold 3 .train auc: 0.53264 val auc: 0.52066
# train fold 4 .train auc: 0.53172 val auc: 0.52477
# saving raw train prediction to: ../submissions/lgb_070_var_199_2019-03-27-09-51-59_train.npy
# saving raw test prediction to: ../submissions/lgb_070_var_199_2019-03-27-09-51-59_test.npy
# cv       mean auc:0.52336

# %%
train_pred = pd.DataFrame()
for  col, f in zip(features, res):
    train_pred[col] = np.load('%s_train.npy' % f).ravel()

# %%
test_pred = pd.DataFrame()
for  col, f in zip(features, res):
    test_pred[col] = np.load('%s_test.npy' % f).mean(axis=1)

# %%
fast_auc(y_train, np.log(train_pred).sum(axis=1) -np.log(1 - train_pred).sum(axis=1))
# Out:
# 0.9232452918532014

# %%
fname = 'lgb_070'

sub = train[['ID_code']].copy()
sub['target'] = np.log(train_pred).sum(axis=1) -np.log(1 - train_pred).sum(axis=1)
sub.target = sub.target.rank() / 200000
print('cv       mean auc:%0.5f' % fast_auc(y_train, sub.target))

print('saving train pred to', '../submissions/%s_train.csv' % fname)
sub.to_csv('../submissions/%s_train.csv' % fname, index=False, float_format='%.6f')

sub = test[['ID_code']].copy()
sub['target'] = np.log(test_pred).sum(axis=1) -np.log(1 - test_pred).sum(axis=1)
sub.target = sub.target.rank() / 200000
print('saving test pred to', '../submissions/%s_test.csv' % fname)
sub.to_csv('../submissions/%s_test.csv' % fname, index=False, float_format='%.6f')

sub.head()
# Out:
# cv       mean auc:0.92325
# saving train pred to ../submissions/lgb_070_train.csv
# saving test pred to ../submissions/lgb_070_test.csv
#   ID_code    target
# 0  test_0  0.789285
# 1  test_1  0.895385
# 2  test_2  0.890305
# 3  test_3  0.865400
# 4  test_4  0.785815

# %%
(np.log(train_pred).sum(axis=1) -np.log(1 - train_pred).sum(axis=1)).head()
# Out:
# 0   -440.586297
# 1   -436.475481
# 2   -441.254642
# 3   -437.622267
# 4   -438.854418
# dtype: float64
